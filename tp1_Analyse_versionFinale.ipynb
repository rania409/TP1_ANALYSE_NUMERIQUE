# %% [markdown]
# ## Exercice 1:<h2>
# >On considère le polynôme $p(x) = (x - 1)^6$.
# >
# >En développant on
# >peut écrire ce même polynôme sous la forme
# >$f(x) = x^6 - 6x^5 + 15x^4 - 20x^3 + 15x^2 - 6x + 1.$
# >
# >1) Avec Matlab évaluer $p(x)$ et $f(x)$ pour $x$ allant de $.998$ à
# >$1.002$ en choisissant des pas de $.0001$.
# >
# >2) Faire un graphique de $f(x)$ et $p(x)$. Commenter.

# %% [markdown]
# <html>
#     <body>
#         <h3><i>==>calcule de p(x) et f(x)</i></h3>
#     </body>
#     </html>

# %%
def p1(x):
    ''' p(x)=(x-1)⁶'''
    return (x-1)**6 # ** puissance 
def p2(x):
    '''version développer de p(x)'''
    return x**6 - 6*x**5 + 15*x**4 - 20*x**3 + 15*x**2 - 6*x + 1

# %%
# le calcul de p1(0.998)
print('p1({})={} '.format(0.998,p1(0.998)))
# le calcul de p2(0.998)
print('p2({})={} '.format(0.998,p2(0.998)))
# Out:
# p1(0.998)=6.400000000000034e-17
# p2(0.998)=1.7763568394002505e-15

# %% [markdown]
# <html>
#     <body>
#         <h5><i>++Nous concluons donc que p1 et p2 ne sont pas égaux</i></h5>
#     </body>
#     </html>

# %%
def horner(P,x):
    n=len(P)
    valeur=P[n-1]
    for i in range(n-2,-1,-1):
        valeur=valeur*x+P[i]
    return valeur

# %%
p=lambda x: (x-1)**6
f=lambda X: x**6 - 6*x**5 + 15*x**4 - 20*x**3 + 15*x**2 - 6*x + 1

# %%
import numpy 
T=[6, -6, 15, -20, 15, -6]
# Expression réduite
print('-------p(i)---------')
for i in numpy.arange(0.998, 1.002, 0.001):
     print('p(i)=' , p(i))

#expression developpée
print('-------f(i)----------')
for i in numpy.arange(0.998, 1.002, 0.001):
      print('f(i)=' , f(i))

print('-------horner--------')
for i in np.arange(0.998, 1.002, 0.001):
       print('horner(T,i)=' , horner(T,i))
# Out:
# -------p(i)---------
# p(i)= 6.400000000000034e-17
# p(i)= 1.0000000000000053e-18
# p(i)= 0.0
# p(i)= 9.999999999993393e-19
# p(i)= 6.400000000000034e-17
# -------f(i)----------
# f(i)= 1.7763568394002505e-15
# f(i)= 0.0
# f(i)= 0.0
# f(i)= -2.6645352591003757e-15
# f(i)= 1.7763568394002505e-15
# -------horner--------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-893b5da1fa88> in <module>
#      13 print('-------horner--------')
#      14 for i in np.arange(0.998, 1.002, 0.001):
# ---> 15        print('horner(T,i)=' , horner(T,i))
#
# NameError: name 'horner' is not defined

# %% [markdown]
# #### 2) Faire un graphique de f(x) et p(x):

# %%
import matplotlib.pyplot as plt
import numpy as np 
x=np.arange(0.998, 1.002, 0.0001)
p=lambda x:(x-1)**6
plt.plot(x,p(x))
plt.xlabel('p')
plt.ylabel('p(x)')
plt.show()

f=lambda x:x**6 - 6*x**5 + 15*x**4 - 20*x**3 + 15*x**2 - 6*x + 1
plt.plot(x,f(x))
plt.xlabel('f')
plt.ylabel('f(x)')
plt.title('solution dans [0.998,0.0001,1.002] ')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Expliquer ces sources d'erreurs !!!!

# %% [markdown]
# <html>
#     <body>
#         <p style="color:DodgerBlue;">Une erreur d'arrondi est la différence entre la valeur approchée calculée d'un nombre et sa valeur mathématique exacte. Des erreurs d'arrondi naissent généralement lorsque des nombres exacts sont représentés dans un système incapable de les exprimer exactement. Les erreurs d'arrondi se propagent au cours des calculs avec des valeurs approchées ce qui peut augmenter l'erreur du résultat final. Dans le système décimal des erreurs d'arrondi sont engendrées, lorsqu'avec une troncature, un grand nombre (peut-être une infinité) de décimales ne sont pas prises en considération. Ce processus d'arrondi apporte des gains de temps de calcul au mépris de la précision.
# En informatique, les ordinateurs représentent les nombres réels sur un nombre fini de bits (représentation en nombre réels à virgule flottante), ce qui ne permet la représentation exacte que d'un petit sous-ensemble des réels. Ainsi, la plupart des calculs conduisent à des résultats approchés qui résultent de la finitude de la représentation.
# L'analyse numérique essaie spécifiquement d'évaluer l'erreur lorsque sont utilisés des approximations de solutions d'équations ou des algorithmes numériques, plus particulièrement quand un nombre fini de chiffres est utilisé pour la représentation des nombres réels.</p>
#     </body>
# </html>

# %% [markdown]
# # EXERCICE 2:
#
# >On considère l'équation : $$ f(x)=x^3+x^2-3x-3=0$$
# >1) Dessiner la courbe de $f$ dans l'intervalle $[-2;2]$, puis trouver des intervalles convenables pour appliquer la méthode de >bisection.
# >
# >2) Utiliser un programme `dicho.m` qui permettra de trouver les solutions de l'équation $f(x)=0$ avec $eps=0.001$.
# >
# >3) Modifier le programme `dicho.m` pour qu'il donne le nombre d'itération nécessaire pour avoir la solution à $eps$ près.

# %% [markdown]
# ## Version Python

# %% [markdown]
# <html>
#     <body>
#         <h2 style="color:MediumSeaGreen;">1) Dessiner la courbe de f dans l'intervalle[-2;2]:</h2>
#     </body>
# </html>

# %%
import matplotlib.pyplot as plt
from numpy import linspace
f=lambda x: x**3+x**2-3*x-3
T=linspace(-2,2,41)
plt.title("solution dans [-2:2] ");
plt.xlabel("x")
plt.ylabel ("f(x)")
plt.grid(True)
plt.plot(T,f(T))

# %% [markdown]
# <html>
#     <body>
#         <h2 style="color:MediumSeaGreen;">2)Utiliser un programme `dicho.py` qui permettra de trouver les solutions de l'équation f(x)=0 avec eps=0.001.</h2>
#     </body>
# </html>

# %% [markdown]
# # Daprés le graph de $f$ il existe 3 solutions :
# - $\alpha_1 \in ]-2;-1.5[$
# - $\alpha_2 \in ]-1.5;-0.5[$
# - $\alpha_3 \in ]1.5;2[$

# %% [markdown]
# ### Donner la version python de `dicho`

# %%
def Dicho(a,b,f,e):
    m=(a+b)/2
    #calcul de la longueur de [a,b]
    err = abs(b-a)
    while err>e:
        if f(a)*f(m)<0:
             b=m
        else:
            a=m
        m=(a+b)/2
        err = b-a
    return m
f=lambda x: x**3+x**2-3*x-3

# %%
Dicho(-2,-1.5,f,0.0001)
# Out:
# -1.732025146484375

# %%
Dicho(-2,-1.5,f,10)
# Out:
# -1.75

# %%
Dicho(-1.5,-0.5,f,0.001)
# Out:
# -0.50048828125

# %%
Dicho(1.5,-2,f,0.001)
# Out:
# -1.125

# %% [markdown]
# <html>
#     <body>
#         <h2 style="color:MediumSeaGreen;">3)Modifier le programme dicho.m pour qu'il donne le nombre d'itération nécessaire pour avoir la solution à  𝑒𝑝𝑠  près.</h2>
#     </body>
# </html>

# %%
def Dichotomie(a,b,f,eps):
    m=(a+b)/2
    err = abs(b-a)
    n=0
    while abs(b-a)>eps:
        n+=1
        if f(a)*f(m)<0:
             b=m
        else:
            a=m
        m=(a+b)/2
    print (" nbr d'itérations nécessaires :", n )
    return m

# %%
Dichotomie(-2,-1.5,f,0.001)
Dichotomie(-1.5,-0.5,f,0.001)
Dichotomie(1.5,2,f,0.001)
# Out:
#  nbr d'itérations nécessaires : 9
#  nbr d'itérations nécessaires : 10
#  nbr d'itérations nécessaires : 9
# 1.73193359375

# %%
import numpy as np
np.floor(2.3)
np.ceil(2.3)
# Out:
# 3.0

# %%
import numpy as np
a=-1.5
b=-0.5
p=8 # précision à 10 ^-8 prés
Dichotomie(a,b,f,10**(-p))
#à 10^-8
# Out:
#  nbr d'itérations nécessaires : 27
# -0.5000000037252903

# %%
interval=[[-2,-1.5],[-1.5,-0.5],[1.5,2]]
for u in interval:
    print(Dichotomie(u[0],u[1],f,10**(-3)))
################################################   
print(Dichotomie(-2,-1.5,f,10**(-3)))
print(Dichotomie(-1.5,-0.5,f,10**(-3)))
print(Dichotomie(1.5,2,f,10**(-3)))
# Out:
#  nbr d'itérations nécessaires : 9
# -1.73193359375
#  nbr d'itérations nécessaires : 10
# -0.50048828125
#  nbr d'itérations nécessaires : 9
# 1.73193359375
#  nbr d'itérations nécessaires : 9
# -1.73193359375
#  nbr d'itérations nécessaires : 10
# -0.50048828125
#  nbr d'itérations nécessaires : 9
# 1.73193359375

# %% [markdown]
# ## Méthode graphique pour la recherche de la solution

# %%
# %matplotlib inline
#import mpld3
#mpld3.enable_notebook()
import numpy as np 
import matplotlib.pyplot as plt

f=lambda x:x**3+x**2-3*x-3

t=np.linspace(1.7,1.75,100)
plt.subplot(2,2,1)
plt.plot(t,f(t),'r')
plt.grid(True)
##########################################
t=np.linspace(1.2,1.4,100)
plt.subplot(2,2,2)
plt.plot(t,f(t),'r')
plt.grid(True)
##########################################
t=np.linspace(1.35,1.4,100)
plt.subplot(2,2,3)
plt.plot(t,f(t),'r')
plt.grid(True)
#########################################
t=np.linspace(1.365,1.367,100)
plt.subplot(2,2,4)
plt.plot(t,f(t),'r')
plt.grid(True)

# %% [markdown]
# ### Methode Dichotomie:

# %% [markdown]
# <html>
#     <body>
#         <h3 style="color:Tomato;">Avantage</h3>
#         <p>*algorithme simple ;
#         <p>*convergence de facon sure </p>
#         <p>*vitesse de convergence constante ;</p>
#         <p>*facilement implementable ;</p>
#     </body>
#
# </html>

# %% [markdown]
# <html>
#     <body>
#         <h3 style="color:Tomato;">Inconvénients :</h3>
#         <p>*necessite f (a) × f (b) inferieur a  0 </p>
#         <p>*necessite la continuite ; </p>
#         <p>*vitesse lente.</p>
#     </body>
#
# </html>

# %% [markdown]
# # EXERCICE 3:
# >On considère l'équation : $$ f(x)=x^3+4x^2-10=0$$
# >1) Dessiner la courbe de $f$ dans l'intervalle $[1;2]$, puis trouver une valeur approché de la solution à 0.001 près (En >utilisant la fonction zoom du graphique).
# >
# >2) Vérifier que cette équation est équivalente aux 3 schéma du point fixe suivant:
# >
# >a) $g_1(x)=\frac{1}{2}\sqrt{10-x^3}=x$.
# >
# >b) $g_2(x)=\sqrt{\displaystyle\frac{10}{4+x}}=x$.
# >
# >c) $g_3(x)=x-x^3-4x^2+10=x$.
# >
# >3) Ecrire puis appliquer  une fonction Matlab que l'on appellera  `pointfixe.m` aux trois schémas précédents en prenant >`x0=1.5;eps=0.001`.
# >
# >4) Quelle est la fonction (parmi $g_1, g_2$ et $g_3$) qui donne la convergence la plus rapide?
# >

# %% [markdown]
# ### Correction <h3>

# %% [markdown]
# <html>
#     <body>
#         <h2 style="color:Violet;">1) Dessiner la courbe de  𝑓  dans l'intervalle  [1;2]:</h2>
#     </body>
# </html>

# %%
# %matplotlib inline
#import mpld3
#mpld3.enable_notebook()
import numpy as np 
import matplotlib.pyplot as plt

f=lambda x:x**3+4*x**2-10

t=np.linspace(1,2,100)
plt.subplot(2,2,1)
plt.plot(t,f(t),'r')
plt.grid(True)
##########################################
t=np.linspace(1.2,1.4,100)
plt.subplot(2,2,2)
plt.plot(t,f(t),'r')
plt.grid(True)
##########################################
t=np.linspace(1.35,1.4,100)
plt.subplot(2,2,3)
plt.plot(t,f(t),'r')
plt.grid(True)
#########################################
t=np.linspace(1.365,1.367,100)
plt.subplot(2,2,4)
plt.plot(t,f(t),'r')
plt.grid(True)

# %% [markdown]
# <html>
#     <body>
#         <h2 style="color:Violet;">2) </h2>
#     </body>
# </html>

# %% [markdown]
# On considère l'équation : $$ f(x)=x^3+4x^2-10=0$$
#
# a) $g(x)=\frac{1}{2}\sqrt{10-x^3}=x$.

# %% [markdown]
#  $$x^3+4x^2-10=0$$
#
#  $$4x^2=10-x^3$$
#
#  $$2x=\sqrt{10-x^3}$$
#
#  $$x=\frac{1}{2}\sqrt{10-x^3}$$
#
# Donc $ f(x)=g(x)$

# %% [markdown]
# ## Calcul symbolique de la dérivée

# %%
from sympy import *
import numpy as np
x, y, z = symbols('x y z')
init_printing(use_unicode=True)
g1=lambda x: 1/2*sqrt(10-x**3)

# %%
dg1=lambdify(x,diff(g1(x),x,1))
dg1(1.365)
# Out:
# -0.5117446282927461

# %% [markdown]
# <html>
#     <body>
#         <h2 style="color:Violet;"> Que pouvez vous conclure à propos des convergences de g1:</h2>
#     </body>
# </html>

# %% [markdown]
# <html>
#     <body>
#         <p style="color:DodgerBlue;">==>Nous concluons que g1 Converge Localement car |g'(x)|inferieur à 1</p>
#     </body>
#  </html>

# %% [markdown]
# ## Justification théoriques pour g2 et g3

# %% [markdown]
# On considère l'équation : $$ f(x)=x^3+4x^2-10=0$$
#
# b) $g(x)=\sqrt{\displaystyle\frac{10}{4+x}}=x$.

# %% [markdown]
# $$x^3+4x^2-10=0$$
# $$x^3+4x^2=10$$
# $$x^2(x+4)=10$$
# $$x^2=\frac{10}{x+4}$$
# $$x=\sqrt{\displaystyle\frac{10}{4+x}}$$
# Donc $ f(x)=g(x)$

# %% [markdown]
# On considère l'équation : $$ f(x)=x^3+4x^2-10=0$$
# c) $g(x)=x-x^3-4x^2+10=x$.

# %% [markdown]
# $$x^3+4x^2-10=0$$
# $$x^3+4x^2-10+x-x=0$$
# $$x^3-4x^2+x-x=10$$
# $$x^3-4x^2+x=x+10$$
# $$4x^2+x=x-x^3+10$$
# $$x=x-x^3-4x^2+10$$
# Donc $ f(x)=g(x)$

# %% [markdown]
# ## Etudier théoriquement la convergences de g2 et g3

# %%
from sympy import *
import numpy as np
x, y, z = symbols('x y z')
init_printing(use_unicode=True)
g2=lambda x: sqrt(10/(4+x))

# %%
dg2=lambdify(x,diff(g2(x),x,1))
dg2(1.365)
# Out:
# -0.12723758423338585

# %%
from sympy import *
import numpy as np
x, y, z = symbols('x y z')
init_printing(use_unicode=True)
g3=lambda x: x-x**3-4*x**2+10

# %%
dg3=lambdify(x,diff(g3(x),x,1))
dg3(1.365)
# Out:
# -15.509675000000001

# %% [markdown]
# <html>
#     <body>
#         <p style="color:DodgerBlue;">==>Nous concluons que g2 et g3 Converge Localement car |g'(x)|inferieur à 1</p>
#     </body>
#  </html>

# %% [markdown]
# #### 4)<h4>

# %% [markdown]
# ### Donner la solution avec un codepython

# %%
f=lambda x:  x**3+4*x**2-10 # la fonction f
g1=lambda x: 1/2*sqrt(10-x**3)
g2=lambda x: sqrt(10/(x+4))
g3=lambda x: x-x**3-4*x**2 + 10


def ptfixe(g,x0,eps,nmax):
    





    print('pas de convergence avec le nombre d''iteration indique')

# %%
ptfixe(g3,1.5,0.0001,30)
# Out:
# pas de convergence avec le nombre diteration indique

# %% [markdown]
# ### quelle est la fonction qui donne la convergence la plus rapide ??
#
# Donner le nombre d'itération pour chaque méthode convergent e
# + $g_2$ donne le resultat en ? itérations
# + $g_1$ donne le resultat en ?
# + $g_3$ est - elle convergente?

# %% [markdown]
# <html>
#     <body>
#         <h3 style="color:Tomato;">Avantages de la méthode de point fixe</h3>
#         <p>C’est une methode beaucoup plus generale que la methode de Newton puisqu’on demande tres peu sur la fonction g (on demande seulement qu’elle soit contractante, elle peut n’etre meme pas derivable.)</p>
#         <p>converge rapidement</p>
#         <p>relativement stable et sensible aux erreur d'arrondi</p>
#     </body>
#
# </html>

# %% [markdown]
# <html>
#     <body>
#         <h3 style="color:Tomato;">Inconvénients de la méthode de point fixe</h3>
#         <p>chaque etape nécessite deux evaluations de fonction</p>
#         <p>nécessite le calcule de la dérivé d une fonction ce qu est difficile numeriquement si on la ne connait pas explicitement </p>
#     </body>
#
# </html>

# %% [markdown]
# # EXERCICE 4:
# >1) On considère la fonction $f(x)=e^{-x}-x$. Ecrire puis appliquer  une fonction Matlab que l'on appellera `newton.m` à la >fonction $f$, en prenant $x0=0$, $eps=0.001$ .
# >
# >2) Montrer que l'équation $f(x)=0$ admet une solution unique que l'on peut obtenir en utilisant la méthode de Newton à partir >de $x0=1$.

# %% [markdown]
# ### Solution Python

# %% [markdown]
# ## Donner la solution entière avecun code python

# %% [markdown]
# <html>
#     <body>
#         <h2 style="color:Violet;"> 1) On considère la fonction  𝑓(𝑥)=𝑒−𝑥−𝑥 . Ecrire puis appliquer une fonction Matlab que l'on appellera newton.m à la >fonction  𝑓 , en prenant  𝑥0=0 ,  𝑒𝑝𝑠=0.001  .</h2>
#     </body>
# </html>

# %%
def newton(f,fprime,a,eps) :
    x1=a
    x2=x1-(f(x1)/fprime(x1))
    while abs(x1-x2)>eps :
        x1=x2
        x2=x1-(f(x1)/fprime(x1))
        m=x2
    return m

# %%
import math 
from sympy import *
from sympy.abc import x
f=lambda x: math.exp(-x)-x
fprime=lambda x: -math.exp(-x)-1

# %%
newton(f,fprime,0,0.001)
# Out:
# 0.5671431650348622

# %% [markdown]
# <html>
#     <body>
#         <h2 style="color:Violet;">2) Montrer que l'équation  𝑓(𝑥)=0  admet une solution unique que l'on peut obtenir en utilisant la méthode de Newton à partir >de  𝑥0=1  </h2>
#     </body>
# </html>

# %%
newton(f,fprime,1,0.001)
# Out:
# 0.567143285989123

# %% [markdown]
# <html>
#     <body>
#         <h3 style="color:Tomato;">Avantages de la méthode de Newton:</h3>
#         <p>Le principal avantage de la méthode résulte de sa convergence au moins quadratique dans
# le cas des racines simples.
# Les hypothèses de départ sont généralement assez peu contraignantes pour une fonction
# qui admet peu de zéros simples.
# La méthode est peu sujette aux instabilités numériques.
# L’algorithme reste d’application pour la détermination de zéros complexes de fonctions
# réelles.</p>
#     </body>
#
# </html>

# %% [markdown]
# <html>
#     <body>
#         <h3 style="color:Tomato;">Inconvénients de la méthode de Newton</h3>
#         <p>Le prinipal inconvénient de la méthode de Newton est la nécessité de calculer la dérivée
# de la fonction dont on cherche un zéro.
# La méthode de Newton peut s’avérer globalement plus lente que la méthode de la sécante
# en raison des évaluations de fonctions.
# Lorsqu’il y a des racines multiples la convergence peut devenir très lente (sauf « aménagements »).</p>
#     </body>
#
# </html>
